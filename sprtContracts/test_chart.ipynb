# %%
# %pylab inline 
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('nfl_standings.csv', index_col=0, header=0)

# %%
df.sample(5)
# Out:
#                       team   w   l playoff
# year
# 2018        houston-texans  11   5     yes
# 2015  new-england-patriots  12   4     yes
# 2014  los-angeles-chargers   9   7      no
# 2019        houston-texans  10   6     yes
# 2018         detroit-lions   6  10      no

# %%
df_playoff = df.loc[df['playoff'] == 'yes', ['team','w', 'playoff']]

# %%
df_playoff
# Out:
#                     team   w playoff
# year
# 2019    baltimore-ravens  14     yes
# 2019       buffalo-bills  10     yes
# 2019   green-bay-packers  13     yes
# 2019      houston-texans  10     yes
# 2019  kansas-city-chiefs  12     yes
# ...                  ...  ..     ...
# 2014  indianapolis-colts  11     yes
# 2014   arizona-cardinals  11     yes
# 2014       detroit-lions  11     yes
# 2014  cincinnati-bengals  10     yes
# 2014    baltimore-ravens  10     yes
#
# [71 rows x 3 columns]

# %%
df_no_playoff = df.loc[df['playoff'] == 'no', ['team','w', 'playoff']]

# %%
df_no_playoff = df.loc[df['playoff'] == 'no', ['team','w', 'playoff']]
sns.distplot(df_playoff['w'],  kde=False, label='playoff teams')
sns.distplot(df_no_playoff['w'],  kde=False, label='non-playoff teams')
	
# Plot formatting
plt.legend(prop={'size': 10})
plt.title('Split Histograms of Wins and Playoff, 2014-2019')
plt.xlabel('Wins')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
